# %% [markdown]
# #### Import Pandas Library

# %%
import pandas as pd
import openpyxl
import random
from datetime import datetime,timedelta

# %% [markdown]
# #### Create a excel workbook with 3 sheets (Customer,Order,Region)

# %% [markdown]
# ##### 1) Create data generation functions of dictonary type

# %%
names = ["Sujay Kumar","Raj Singh","Keshav Sinha","Ashutosh Dash","Piyush Kumar"]
cities=["Bhubaneswar","Bhagalpur","Pune","Mumbai","Hyderabad"]

def generate_customer_data(row:int)->dict:
    return {
        "customer_id":id(row),
        "customer_name":random.choice(names),
        "payment_status":random.choice(["Paid","Not Paid"])
        }


def generate_order_data(row:int)->dict:
    return {
        "customer_id":id(row),
        "order_date":(datetime(2026,10,1)-timedelta(days=random.randint(0,2000))).strftime("%Y-%m-%d")
    }

def generate_region_data(row:int)->dict:
    return {
        "customer_id":id(row),
        "city":random.choice(cities)
    }

# %% [markdown]
# ##### 2) Create a function that convert list of dictonary object to DataFrame

# %%
from pandas import DataFrame
def generate_dataFrame(data:list)-> DataFrame:
    return pd.DataFrame(data)

# %% [markdown]
# ##### 3) Generate the customer details workbook

# %%
def create_excel_cust_workbook():
    FILE_NAME = "Customer_details.xlsx"
    with pd.ExcelWriter(FILE_NAME,engine = "openpyxl") as writer:
        customer_data = [generate_customer_data(i) for i in range(1,50+1)]
        order_data = [generate_order_data(i) for i in range(1,50+1)]
        region_data = [generate_order_data(i) for i in range(1,50+1)]
        cust_df = generate_dataFrame(customer_data)
        order_df = generate_dataFrame(order_data)
        region_df = generate_dataFrame(region_data)
        cust_df.to_excel(writer,sheet_name="Customers",index=False)
        order_df.to_excel(writer,sheet_name="Orders",index=False)
        region_df.to_excel(writer,sheet_name="Region",index=False)
    print(f"{FILE_NAME} excel file created successfully")


create_excel_cust_workbook()
# Out:
# Customer_details.xlsx excel file created successfully

# %% [markdown]
# #### Pyspark Practice

# %% [markdown]
# ##### Install and import Pyspark Library

# %%
pip install pyspark --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyspark
#   Downloading pyspark-4.2.0.tar.gz (450.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.1/450.1 MB 7.1 MB/s eta 0:00:00m eta 0:00:010:00:02
#   Preparing metadata (setup.py) ... done
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.0/203.0 kB 10.5 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-4.2.0-py2.py3-none-any.whl size=450798562 sha256=e1dd598be971b24901266eeeda7279bf511d2c1019a7384e3c59b81494ead655
#   Stored in directory: /home/sujay/.cache/pip/wheels/a7/94/11/60b8a9f7f3b008ee04da64b003784e8bbaf1d5473f05b412dc
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.9 pyspark-4.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show pyspark
# Out:
# Name: pyspark
# Version: 4.2.0
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: Apache-2.0
# Location: /home/sujay/.local/lib/python3.12/site-packages
# Requires: py4j
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("SujaySpark")
    .getOrCreate()
)
# Out:
# JAVA_HOME is not set
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 spark = (
#       4     SparkSession.builder
#       5     .appName("SujaySpark")
# ----> 6     .getOrCreate()
#       7 )
#
# File ~/.local/lib/python3.12/site-packages/pyspark/sql/session.py:559, in SparkSession.Builder.getOrCreate(self)
#     557     sparkConf.set(key, value)
#     558 # This SparkContext may be an existing one.
# --> 559 sc = SparkContext.getOrCreate(sparkConf)
#     560 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     561 # by all sessions.
#     562 session = SparkSession(sc, options=self._options)
#
# File ~/.local/lib/python3.12/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File ~/.local/lib/python3.12/site-packages/pyspark/core/context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)    219         memory_profiler_cls,
#     220     )
#
# File ~/.local/lib/python3.12/site-packages/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File ~/.local/lib/python3.12/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.
